# %%
# %load_ext autoreload
# %autoreload 2

# %%
import chesspi_utils

# %%
from matplotlib import pyplot as plt

# %%
import cv2

# %%
image_name = "chess_board.png"

# %%
image = cv2.imread(image_name)

# %%
plt.imshow(image)
plt.show()

# %%
image.dtype
# Out:
# dtype('uint8')

# %%
image.shape
# Out:
# (720, 720, 3)

# %%
sqr_1 = image[0:90, 0:90]

# %%
sqr_1.dtype
# Out:
# dtype('uint8')

# %%
cv2.imwrite("sqr_1.jpg", sqr_1)
# Out:
# True

# %%
chesspi_utils.extract_squares_form_starting_position("chess_board3.png", 1)
